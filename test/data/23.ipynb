# %%
import datetime


current_time = datetime.datetime.now()
_timestamp = current_time.strftime("%Y:%m:%d-%H:%M:%S.%f")
_timestamp
# Out:
# '2025:05:08-14:02:20.067274'

# %%
RES_TOPIC = "edgeplatform/hub/['STSW000001', 'STSW000002', 'STSW000003', 'STSW000004', 'STSW000005']"
base = "edgeplatform/hub"
edge = ['STSW000001', 'STSW000002', 'STSW000003', 'STSW000004', 'STSW000005'] 
edgeIds = str(edge)
# for i in range(len(edgeId)):
#     print(edgeId[i])
#edgeIds
for edgeId in edgeIds:
    topic = f"{base}/{edgeId}"
    print(edgeId)
# Out:
# [
# '
# S
# T
# S
# W
# 0
# 0
# 0
# 0
# 0
# 1
# '
# ,
#
# '
# S
# T
# S
# W
# 0
# 0
# 0
# 0
# 0
# 2
# '
# ,
#
# '
# S
# T
# S
# W
# 0
# 0
# 0
# 0
# 0
# 3
# '
# ,
#
# '
# S
# T
# S
# W
# 0
# 0
# 0
# 0
# 0
# 4
# '
# ,
#
# '
# S
# T
# S
# W
# 0
# 0
# 0
# 0
# 0
# 5
# '
# ]

# %%
import ast
edge = ast.literal_eval(edgeIds)

edge
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 import ast
# ----> 2 edge = ast.literal_eval(edgeIds)
#       4 edge
#
# File /usr/lib/python3.8/ast.py:99, in literal_eval(node_or_string)
#      97                 return left - right
#      98     return _convert_signed_num(node)
# ---> 99 return _convert(node_or_string)
#
# File /usr/lib/python3.8/ast.py:82, in literal_eval.<locals>._convert(node)
#      80     return tuple(map(_convert, node.elts))
#      81 elif isinstance(node, List):
# ---> 82     return list(map(_convert, node.elts))
#      83 elif isinstance(node, Set):
#      84     return set(map(_convert, node.elts))
#
# File /usr/lib/python3.8/ast.py:98, in literal_eval.<locals>._convert(node)
#      96         else:
#      97             return left - right
# ---> 98 return _convert_signed_num(node)
#
# File /usr/lib/python3.8/ast.py:75, in literal_eval.<locals>._convert_signed_num(node)
#      73     else:
#      74         return - operand
# ---> 75 return _convert_num(node)
#
# File /usr/lib/python3.8/ast.py:66, in literal_eval.<locals>._convert_num(node)
#      64 def _convert_num(node):
#      65     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 66         _raise_malformed_node(node)
#      67     return node.value
#
# File /usr/lib/python3.8/ast.py:63, in literal_eval.<locals>._raise_malformed_node(node)
#      62 def _raise_malformed_node(node):
# ---> 63     raise ValueError(f'malformed node or string: {node!r}')
#
# ValueError: malformed node or string: <_ast.Name object at 0x77b4c66df700>
