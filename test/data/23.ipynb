# %%
import datetime


current_time = datetime.datetime.now()
_timestamp = current_time.strftime("%Y:%m:%d-%H:%M:%S.%f")
_timestamp

# %%
RES_TOPIC = "edgeplatform/hub/['STSW000001', 'STSW000002', 'STSW000003', 'STSW000004', 'STSW000005']"
base = "edgeplatform/hub"
edge = ['STSW000001', 'STSW000002', 'STSW000003', 'STSW000004', 'STSW000005'] 
edgeIds = str(edge)
# for i in range(len(edgeId)):
#     print(edgeId[i])
#edgeIds
for edgeId in edgeIds:
    topic = f"{base}/{edgeId}"
    print(edgeId)

# %%
import ast
edge = ast.literal_eval(edgeIds)

edge[1]

# %%
import time
import datetime

now = datetime.datetime.now()

end = datetime.datetime.now()


print((end-now)>1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 9
#       4 now = datetime.datetime.now()
#       6 end = datetime.datetime.now()
# ----> 9 print((end-now)>1)
#
# TypeError: '>' not supported between instances of 'datetime.timedelta' and 'int'

# %%
import json
data = {"CRC":"12345678","VID":"TRAC000001", "edgeTy":"TRC", "timestamp":"2025-06-13 17:18:49.146750", "command":"80302", "data":{"accel":0,"autoDrivingStatus":0,"brake":0,"brakeStatus":0,"drivingDistance":0,"emergencyLight":0,"gearStatus":0,"mdpsAngle":0,"turnSignal":0,"wheelSpeed":0,"yawRate":0}}

json_data = json.dumps(data)
data = json.loads(json_data)

data["data"][""]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 7
#       4 json_data = json.dumps(data)
#       5 data = json.loads(json_data)
# ----> 7 data["data"][1]
#
# KeyError: 1
