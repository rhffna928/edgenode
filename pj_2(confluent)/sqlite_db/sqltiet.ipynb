# %%
import sqlite3

con = sqlite3.connect("./test.db")
sqlite3.Connection

cursor = con.cursor()

sql = """
    CREATE TABLE STREET_SWEEPER_INFO (
    VEHICLE_ID TEXT,
    BLOWER_RUN TEXT,
    SIDE_LEFT_BRUSH_RUN TEXT,
    SIDE_RIGHT_BRUSH_RUN TEXT,
    FRONT_BRUSH_RUN TEXT,
    FLAP_RUN TEXT,
    WATER_PUMP_RUNS TEXT,
    REGIST_DATE TEXT DEFAULT (DATETIME('now', 'localtime'))
);
"""
cursor.execute(sql)
con.commit()

# %%
import sqlite3

con = sqlite3.connect("./test.db")
sqlite3.Connection

cursor = con.cursor()

sql = """
    CREATE TABLE VEHICLE_ING_INFO (
    I_INDEX INTEGER PRIMARY KEY AUTOINCREMENT,
    VEHICLE_ID TEXT,
    VEHICLE_TYPE TEXT,
    TTC TEXT,
    ING_ACCELERAION TEXT,
    HANDLE_ANGLE TEXT,
    C_SEQ TEXT,
    LATITUDE TEXT,
    LONGITUDE TEXT,
    C_TIMESTAMP TEXT,
    INTER_VEHICLE_DISTANCE TEXT,
    SPEED TEXT,
    LATERAL_ACCELERATION TEXT,
    WIPER_STATUS TEXT,
    MDPS_ANGLE TEXT,
    DRIVING_DISTANCE TEXT,
    EMERGENCY_LIGHT TEXT,
    WHEEL_SPEED TEXT,
    AUTO_DRIVING_STATUS TEXT,
    TRANSMISSION TEXT,
    V_TIMESTAMP TEXT DEFAULT  (DATETIME('now', 'localtime')),
    TURN_SIGNAL TEXT,
    YAW_RATE TEXT,
    BRAKING_STATUS TEXT,
    BRAKING_TYPE TEXT,
    SENSOR_TYPE TEXT,
    S_TIMESTAMP TEXT,
    SENSOR_STATUS TEXT,
    SENSOR_ID TEXT,
    GOAL_LONGITUDE TEXT,
    J_SEQ TEXT,
    MOTION_PLAN TEXT,
    GOAL_SPEED TEXT,
    TARGET_OBJ_SPEED TEXT,
    TARGET_OBJ_PREDICT TEXT,
    TARGET_OBJ TEXT,
    GOAL_ACCELERATION TEXT,
    TARGET_OBJ_DISTANCE TEXT,
    J_TIMESTAMP TEXT,
    GOAL_LATITUDE TEXT,
    GOAL_WHEEL_ANGLE TEXT,
    L_LATITUDE TEXT,
    L_TIMESTAMP TEXT,
    L_SPEED TEXT,
    HEADING TEXT,
    L_LONGITUDE TEXT,
    LANE TEXT,
    OBSTACLE_ARR TEXT,
    TRAFFIC_LIGHT_ARR TEXT,
    T_TIMESTAMP TEXT,
    TRAFFIC_LIGHT_ID TEXT,
    TRAFFIC_LIGHT TEXT,
    OBSTACLE_WIDTH TEXT,
    OBSTACLE_LNG_SPEED TEXT,
    OBSTACLE_ID TEXT,
    OBSTACLE_LATERAL_ABS_SPEED TEXT,
    O_TIMESTAMP TEXT,
    OBSTACLE_DISTANCE TEXT,
    OBSTACLE_HEADING TEXT,
    OBSTACLE_LATERAL_SPEED TEXT,
    OBSTACLE_LNG_ABS_SPEED TEXT,
    OBSTACLE_TYPE TEXT,
    REGIST_DATE TEXT DEFAULT CURRENT_TIMESTAMP,
    REAL_DIV TEXT,
    ARRIVAL_NAME TEXT,
    ARRIVAL_DISTANCE TEXT,
    ARRIVAL_TIME TEXT,
    ARRIVAL_ID TEXT,
    GEAR_STATUS TEXT,
    BRAKE_STATUS TEXT,
    LOAD_CAPACITY TEXT,
    BATTERY_REMAINING_CAPACITY TEXT,
    BATTERY_VOLTAGE TEXT,
    BATTERY_TEMPERATURE TEXT,
    BRAKE TEXT,
    BRAKE_TYPE TEXT,
    ACCEL TEXT,
    WORK_RATE TEXT
);
"""
cursor.execute(sql)
con.commit()

# %%
import sqlite3

con = sqlite3.connect("./test.db")
sqlite3.Connection

cursor = con.cursor()

sql = """
    CREATE TABLE VEHICLE_LIST (
    I_INDEX INTEGER PRIMARY KEY AUTOINCREMENT,
    VEHICLE_ID TEXT,
    VEHICLE_NAME TEXT,
    VEHICLE_TYPE TEXT,
    USER_ID TEXT,
    "REGIST_DATE" TEXT DEFAULT (DATETIME('now', 'localtime'))
);
"""
cursor.execute(sql)
con.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 18
#       6 cursor = con.cursor()
#       8 sql = """
#       9     CREATE TABLE VEHICLE_LIST (
#      10     I_INDEX INTEGER PRIMARY KEY AUTOINCREMENT,
#    (...)
#      16 );
#      17 """
# ---> 18 cursor.execute(sql)
#      19 con.commit()
#
# OperationalError: table VEHICLE_LIST already exists

# %%
import sqlite3

con = sqlite3.connect("./test.db")
sqlite3.Connection

cursor = con.cursor()

sql = """
    CREATE TABLE LOCATION_INFO (
    I_INDEX INTEGER PRIMARY KEY AUTOINCREMENT,
    VEHICLE_ID TEXT,
    VEHICLE_TYPE TEXT,
    LATITUDE TEXT,
    LONGITUDE TEXT,
    SPEED TEXT,
    HEADING TEXT
);
"""
cursor.execute(sql)
con.commit()

# %%
import sqlite3

con = sqlite3.connect("./test.db")
sqlite3.Connection

cursor = con.cursor()

sql = """
    CREATE TABLE VEHICLE_INFO (
    I_INDEX INTEGER PRIMARY KEY AUTOINCREMENT,
    VEHICLE_ID TEXT,
    VEHICLE_TYPE TEXT,
    MDPS_ANGLE TEXT,
    DRIVING_DISTANCE TEXT,
    EMERGENCY_LIGHT TEXT,
    WHEEL_SPEED TEXT,
    AUTO_DRIVING_STATUS TEXT,
    TRANSMISSION TEXT,
    V_TIMESTAMP TEXT DEFAULT CURRENT_TIMESTAMP,
    TURN_SIGNAL TEXT,
    YAW_RATE TEXT,
    T_TIMESTAMP TEXT,
    REGIST_DATE TEXT DEFAULT (DATETIME('now', 'localtime')),
    GEAR_STATUS TEXT,
    LOAD_CAPACITY TEXT,
    BATTERY_REMAINING_CAPACITY TEXT,
    BATTERY_VOLTAGE TEXT,
    BATTERY_TEMPERATURE TEXT,
    BRAKE TEXT,
    BRAKE_TYPE TEXT,
    BRAKE_STATUS TEXT,
    ACCEL TEXT,
    WORK_RATE TEXT
);
"""
cursor.execute(sql)
con.commit()

# %%
import sqlite3

con = sqlite3.connect("./test.db")
sqlite3.Connection

cursor = con.cursor()

sql = """
CREATE TABLE "TRACTOR_INFO" (
    "VEHICLE_ID" TEXT,
    "ENGINE_SPEED" REAL,
    "ACTUAL_ENGINE_PERCENT_TORQUE" REAL,
    "ENGINE_COOLANT_TEMPERATURE" REAL,
    "AMBIENT_AIR_TEMPERATURE" REAL,
    "ENGINE_EXHAUST_GAS_TEMPERATURE" REAL,
    "FUEL_LEVEL" REAL,
    "REPRESENTS_POSITIONOF_HITCH" REAL,
    "PTO_LAMP" INTEGER,
    "FWD_LAMP" INTEGER,
    "SHIFT_LAMP" INTEGER,
    "SHIFT_AUTO_LAMP" INTEGER,
    "KEYSWITCH_BATTERY_POTENTIAL" REAL,
    "GPS_SENSOR_STATUS" INTEGER,
    "NTRIP_STATUS" INTEGER,
    "DRAFT_SENSOR_STATUS" INTEGER,
    "HITCH_SENSOR_STATUS" INTEGER,
    "VEHICLE_SPEED_SENSOR_STATUS" INTEGER,
    "EMERGENCY_STOP" INTEGER,
    "REGIST_DATE" TEXT DEFAULT (DATETIME('now', 'localtime'))
);
"""
cursor.execute(sql)
con.commit()

# %%
    import sqlite3

con = sqlite3.connect("./test.db")
sqlite3.Connection

cursor = con.cursor()

sql = """
CREATE TABLE "TRACTOR_INFO" (
    "VEHICLE_ID" TEXT,
    "ACTUALENGINEPERCENTTORQUE" REAL,
    "AMBIENTAIRTEMPERATURE" REAL,
    "BACKWARDSOLENOID" INTEGER,
    "CLUTCHPEDALSENSORORSWITCH" INTEGER,
    "DIFFLOCKSOLENOIDCIRCUIT" INTEGER,
    "DRAFTSENSORSTATUS" INTEGER,
    "EMERGENCYSTOP" INTEGER,
    "ENGINECOOLANTTEMPERATURE" REAL,
    "ENGINEEXHAUSTGASTEMPERATURE" REAL,
    "ENGINERPMCANTIMEOUT" INTEGER,
    "ENGINESPEED" REAL,
    "FORWARDSOLENOID" INTEGER,
    "FUELLEVEL" REAL,
    "FWDLAMP" INTEGER,
    "GEAR1SOLENOIDCIRCUIT" INTEGER,
    "GEAR2OLENOIDCIRCUIT" INTEGER,
    "GEAR3SOLENOIDCIRCUIT" INTEGER,
    "GPSSENSORSTATUS" INTEGER,
    "HIGHPRESSUREFILTERCLOGGINGWARNSWITCH" INTEGER,
    "HITCHSENSORSTATUS" INTEGER,
    "KEYSWITCHBATTERYPOTENTIAL" REAL,
    "NTRIPSTATUS" INTEGER,
    "OILTEMPSENSOR" INTEGER,
    "P3ATTMDOWNPOWER" INTEGER,
    "P3ATTMPOSITIONSENSOR" INTEGER,
    "P3ATTMUPPOWER" INTEGER,
    "P3BATTERYVOLTAGE18V" INTEGER,
    "P3CONTOLLERPOWER" INTEGER,
    "P3EXTBUTTONDOWN" INTEGER,
    "P3EXTBUTTONUP" INTEGER,
    "P3UPDOWNSOLENOIDSHORT" INTEGER,
    "PTOLAMP" INTEGER,
    "PTOSOLENOIDCIRCUIT" INTEGER,
    "QTSOLENOID" INTEGER,
    "REPRESENTSPOSITIONOFHITCH" REAL,
    "SHIFTAUTOLAMP" INTEGER,
    "SHIFTHIGHSOLENOID" INTEGER,
    "SHIFTLAMP" INTEGER,
    "SHIFTLOWSOLENOID" INTEGER,
    "SHIFTOILPRESSURESWITCH" INTEGER,
    "SHUTTLESWITCH" INTEGER,
    "TEMPCOMPENSATEDSOLENOID" INTEGER,
    "VEHICLESPEEDSENSORSTATUS" INTEGER,
    "WD4SOLENOID" INTEGER
    "REGIST_DATE" TEXT DEFAULT (DATETIME('now', 'localtime'))
);
"""
cursor.execute(sql)
con.commit()

# %%
import sqlite3

con = sqlite3.connect("./test.db")
cursor = con.cursor()

sql = """
CREATE TABLE "WORK_INFO_TRACTOR" (
    "VEHICLE_ID" TEXT,
    "WORK_AREA" JSON,  
    "WORK_PATH" JSON,  
    "REGIST_DATE" TEXT DEFAULT (DATETIME('now', 'localtime'))
);
"""

cursor.execute(sql)
con.commit()

# %%
import sqlite3

con = sqlite3.connect("./test.db")
cursor = con.cursor()

sql = """
CREATE TABLE "VEHICLE_EVENT" (
    "VEHICLE_ID" TEXT,
    "VEHICLE_TYPE" TEXT,
    "EVENT_CODE" TEXT,
    "EVENT_DESCRIPTION" TEXT,
    "REGIST_DATE" TEXT DEFAULT (DATETIME('now', 'localtime'))
);
"""

cursor.execute(sql)
con.commit()

# %%
import sqlite3

con = sqlite3.connect("./test.db")
cursor = con.cursor()

sql = """
CREATE TABLE "GLOBAL_PLAN_HISTORY" (
    "REQUEST_DATE" TEXT,
    "REQUEST_AREA" TEXT,  -- JSON 데이터는 SQLite에서 TEXT로 저장
    "RESULT" TEXT,        -- JSON 데이터는 SQLite에서 TEXT로 저장
    "MISSION_PROGRESS" INTEGER,  -- PostgreSQL의 int4를 SQLite의 INTEGER로 변환
    "REGIST_DATE" TEXT DEFAULT (DATETIME('now', 'localtime'))
);
"""

cursor.execute(sql)
con.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 3
#       1 import sqlite3
# ----> 3 con = sqlite3.connect("~mk/python/kafka/pj_2(confluent)/pj(confluent)/test/sqlite_db/test.db")
#       4 cursor = con.cursor()
#       6 sql = """
#       7 CREATE TABLE "GLOBAL_PLAN_HISTORY" (
#       8     "REQUEST_DATE" TEXT,
#    (...)
#      13 );
#      14 """
#
# OperationalError: unable to open database file

# %%
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "P3_ATTM_DOWN_POWER" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "P3_ATTM_POSITION_SENSOR" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "P3_ATTM_UP_POWER" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "P3_BATTERY_VOLTAGE_18V" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "P3_CONTOLLER_POWER" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "P3_EXT_BUTTON_DOWN" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "P3_EXT_BUTTON_UP" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "P3_UP_DOWN_SOLENOID_SHORT" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "SHUTTLE_SWITCH" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "SHIFT_OIL_PRESSURE_SWITCH" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "HIGH_PRESSURE_FILTER_CLOGGING_WARN_SWITCH" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "QT_SOLENOID" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "WD4_SOLENOID" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "SHIFT_LOW_SOLENOID" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "SHIFT_HIGH_SOLENOID" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "FORWARD_SOLENOID" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "BACKWARD_SOLENOID" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "TEMP_COMPENSATED_SOLENOID" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "GEAR1_SOLENOID_CIRCUIT" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "GEAR2_SOLENOID_CIRCUIT" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "GEAR3_SOLENOID_CIRCUIT" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "PTO_SOLENOID_CIRCUIT" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "DIFF_LOCK_SOLENOID_CIRCUIT" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "CLUTCH_PEDAL_SENSOR_OR_SWITCH" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "ENGINE_RPM_CAN_TIMEOUT" INTEGER;
ALTER TABLE "TRACTOR_INFO" ADD COLUMN "OIL_TEMP_SENSOR" INTEGER;
