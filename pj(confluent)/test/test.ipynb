# %%
import jpype
import jpype.imports
from jpype.types import *
from datetime import datetime
import json

# JVM 시작
jpype.startJVM()
jpype.addClassPath("~/mk/python/kafka/pj_2(confluent)/pj(confluent)/watosysEncrypt_not_otp_v1.0.0.jar")
jvm_msg_encrypt_class = jpype.JClass("watosys.utils.eg.msg.MsgEncrypt")
json_message = {
    0 : {"topicName":"return/global_planning","plan":[{"STSW000001":[[22420232,[36.609286,127.287869],0],[22420261,[36.61033132,127.2848557],1],[22420265,[36.61033237,127.2848132],2],[22420264,[36.61036086,127.2848038],2],[22420061,[36.6103738,127.2855318],3]]}],"missionArea":"null","strategy":"MIN_TOTAL_TIME"},
    1 : {"vehicleId":"TRAC000001","vehicleType":"T","eventCode": "warning","eventDescription": "주변 장애물 감지","registDate":"2024-11-04 17:24:35"},
    2 : {"vehicleId":"STSW000001","eventCode":"warning"},
    3 : {'resultCd': 0, 'resultMssage': "globalpath write 성공"},
    4 : {'resultCd': 0, 'resultMssage': 'init 성공 응답 22', 'userId': '1', 'edgeList': [['TRAC000003', '트랙터03', 'T']]}
}



now = datetime.now()
now_str = now.strftime("%Y-%m-%d %H:%M:%S.%f")
_edgeid = str("STSW000001")

for i in range(len(json_message)):
    data_message = json.dumps(json_message[i], ensure_ascii=False)

    data = jvm_msg_encrypt_class.encode(now_str,_edgeid,data_message)
    print(data,"\n")

# json_message = {"data":"WT2vIhz5G1rJXJ6gLqBvIS42U5galM0DTjyePz3SrAl20aLDiM5xQSBDWttJ3k4c0lzsPLORg794BP2U1J3oVg=="}
# data_message = json.dumps(json_message, ensure_ascii=False)
# try:
#     decode_data = jvm_msg_encrypt_class.decode(now_str,data_message)
    
#     print(decode_data)
# except Exception as err:
#     print(err)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File org.jpype.classloader.DynamicClassLoader.java, in org.jpype.classloader.DynamicClassLoader.addFile()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.io.FileNotFoundException             Traceback (most recent call last)
# Cell In[17], line 9
#       7 # JVM 시작
#       8 jpype.startJVM()
# ----> 9 jpype.addClassPath("../watosysEncrypt_not_otp_v1.0.0.jar")
#      10 jvm_msg_encrypt_class = jpype.JClass("watosys.utils.eg.msg.MsgEncrypt")
#      11 json_message = {
#      12     0 : {"topicName":"return/global_planning","plan":[{"STSW000001":[[22420232,[36.609286,127.287869],0],[22420261,[36.61033132,127.2848557],1],[22420265,[36.61033237,127.2848132],2],[22420264,[36.61036086,127.2848038],2],[22420061,[36.6103738,127.2855318],3]]}],"missionArea":"null","strategy":"MIN_TOTAL_TIME"},
#      13     1 : {"vehicleId":"TRAC000001","vehicleType":"T","eventCode": "warning","eventDescription": "주변 장애물 감지","registDate":"2024-11-04 17:24:35"},
#    (...)
#      16     4 : {'resultCd': 0, 'resultMssage': 'init 성공 응답 22', 'userId': '1', 'edgeList': [['TRAC000003', '트랙터03', 'T']]}
#      17 }
#
# File /usr/local/lib/python3.12/dist-packages/jpype/_classpath.py:67, in addClassPath(path1)
#      65             classLoader.addFile(Paths.get(str(path)))
#      66     else:
# ---> 67         classLoader.addFile(Paths.get(str(path1)))
#      68 _CLASSPATHS.append(path1)
#
# java.io.FileNotFoundException: java.io.FileNotFoundException: /tmp/ipykernel_1080467/../watosysEncrypt_not_otp_v1.0.0.jar

# %%
import datetime

timestamp = "2025-03-25 10:00:13.844000"
now = datetime.datetime.now()
endtime = now.strftime("%Y-%m-%d %H:%M:%S.%f")
start_time = datetime.datetime.strptime(timestamp, '%Y-%m-%d %H:%M:%S.%f')
delay = (now - start_time).total_seconds() * 1000

round(delay,4)

# %%
from PostgreController import PostgreController
import configparser
import os
from pathlib import Path
import pandas as pd

host = '223.130.131.234'
port = '30050'
id = 'postgres'
pw = 'nM!Q2w3e4r'
db_name = 'edge-hub'
dbctrl = PostgreController(host,port,id,pw,db_name)

db_conditions = {'tablename':'"VEHICLE_LIST" as vl'}
db_conditions['select'] = 'vl."VEHICLE_ID", vl."VEHICLE_NAME", vl."VEHICLE_TYPE"'
db_conditions['orderby'] = 'order by vl."VEHICLE_ID"'
db_conditions['and_where'] = {}
db_conditions['and_where']['vl."USER_ID"'] = '1'
db_conditions['offset'] = "0"
db_conditions['limit'] = "10"

#print(db_conditions)

result = dbctrl.base_select(db_conditions)

#result

df = pd.DataFrame(result['datas'])
df
# Out:
# SELECT vl."VEHICLE_ID", vl."VEHICLE_NAME", vl."VEHICLE_TYPE" FROM "VEHICLE_LIST" as vl  WHERE ( vl."USER_ID" = '1'  )  OFFSET 0 LIMIT 10
#    VEHICLE_ID VEHICLE_NAME VEHICLE_TYPE
# 0  STSW000001        청소차01            S
